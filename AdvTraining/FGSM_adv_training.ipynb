# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
import matplotlib.pyplot as plt

# Load the perturbed fgsm training dataset
perturbed_train_data = np.load('../AttackMethods/perturbed_mnist_2LFCN_FGSM_train.npz')
perturbed_train_images = perturbed_train_data['images']
perturbed_train_labels = perturbed_train_data['labels']

# Load the clean test dataset
mnist = tf.keras.datasets.mnist
(_, _), (test_images, test_labels) = mnist.load_data()
test_images = test_images / 255.0  # Normalize pixel values

# Load the perturbed fgsm test dataset
perturbed_test_data_FGSM = np.load('../AttackMethods/perturbed_mnist_2LFCN_FGSM_test.npz')
perturbed_test_images_FGSM = perturbed_test_data_FGSM['images']
perturbed_test_labels_FGSM = perturbed_test_data_FGSM['labels']

# Load the perturbed CW test dataset
perturbed_test_data_CW = np.load('../AttackMethods/perturbed_mnist_2LFCN_CW_test.npz')
perturbed_test_images_CW = perturbed_test_data_CW['images']
perturbed_test_labels_CW = perturbed_test_data_CW['labels']

# Load the perturbed DF test dataset
perturbed_test_data_DF = np.load('../AttackMethods/perturbed_mnist_2LFCN_DF_test.npz')
perturbed_test_images_DF = perturbed_test_data_DF['images']
perturbed_test_labels_DF = perturbed_test_data_DF['labels']


# Load the FCN model (replace with your model loading code)
fcn_model = models.load_model("../Models/Mnist/mnist_model_2LFCN.karas")

# Compile the model
fcn_model.compile(
    optimizer='adam',
    loss=SparseCategoricalCrossentropy(),
    metrics=[SparseCategoricalAccuracy()]
)

# Evaluate on clean test set before any adversarial training
test_loss, initial_clean_test_accuracy = fcn_model.evaluate(test_images, test_labels, verbose=2)

# Evaluate on perturbed test sets before any adversarial training
test_loss, initial_perturbed_test_accuracy_FGSM = fcn_model.evaluate(perturbed_test_images_FGSM, perturbed_test_labels_FGSM, verbose=2)
test_loss, initial_perturbed_test_accuracy_CW = fcn_model.evaluate(perturbed_test_images_CW, perturbed_test_labels_CW, verbose=2)
test_loss, initial_perturbed_test_accuracy_DF = fcn_model.evaluate(perturbed_test_images_DF, perturbed_test_labels_DF, verbose=2)


# Adversarial training parameters
epochs = 5
batch_size = 100

# Lists to store accuracy for plotting
clean_test_accuracies = [initial_clean_test_accuracy]
perturbed_test_accuracies_FGSM = [initial_perturbed_test_accuracy_FGSM]
perturbed_test_accuracies_CW = [initial_perturbed_test_accuracy_CW]
perturbed_test_accuracies_DF = [initial_perturbed_test_accuracy_DF]


# Adversarial training loop
for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")

    # Train on perturbed examples
    fcn_model.fit(perturbed_train_images, perturbed_train_labels, epochs=1, batch_size=batch_size, verbose=2)

    # Evaluate on clean test set
    test_loss, clean_test_accuracy = fcn_model.evaluate(test_images, test_labels, verbose=2)
    clean_test_accuracies.append(clean_test_accuracy)

    # Evaluate on perturbed test sets
    test_loss, perturbed_test_accuracy_FGSM = fcn_model.evaluate(perturbed_test_images_FGSM, perturbed_test_labels_FGSM, verbose=2)
    perturbed_test_accuracies_FGSM.append(perturbed_test_accuracy_FGSM)
    test_loss, perturbed_test_accuracy_CW = fcn_model.evaluate(perturbed_test_images_CW, perturbed_test_labels_CW, verbose=2)
    perturbed_test_accuracies_CW.append(perturbed_test_accuracy_CW)
    test_loss, perturbed_test_accuracy_DF = fcn_model.evaluate(perturbed_test_images_DF, perturbed_test_labels_DF, verbose=2)
    perturbed_test_accuracies_DF.append(perturbed_test_accuracy_DF)

# Plot the results
plt.plot(range(0, epochs + 1), clean_test_accuracies, label='Clean Test Accuracy', marker='o')
plt.plot(range(0, epochs + 1), perturbed_test_accuracies_FGSM, label='Perturbed Test Accuracy (FGSM)', marker='o')
plt.plot(range(0, epochs + 1), perturbed_test_accuracies_CW, label='Perturbed Test Accuracy (CW)', marker='o')
plt.plot(range(0, epochs + 1), perturbed_test_accuracies_DF, label='Perturbed Test Accuracy (DF)', marker='o')
plt.title('Adversarial Training (FGSM,2LFCN)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# 313/313 - 1s - loss: 0.0372 - sparse_categorical_accuracy: 0.9895 - 1s/epoch - 5ms/step
# 157/157 - 1s - loss: 4.2405 - sparse_categorical_accuracy: 0.2556 - 868ms/epoch - 6ms/step
# 157/157 - 1s - loss: 2.2345 - sparse_categorical_accuracy: 0.0144 - 617ms/epoch - 4ms/step
# 157/157 - 1s - loss: 1.3042 - sparse_categorical_accuracy: 0.0144 - 649ms/epoch - 4ms/step
# Epoch 1/5
# 200/200 - 4s - loss: 0.8783 - sparse_categorical_accuracy: 0.7340 - 4s/epoch - 20ms/step
# 313/313 - 1s - loss: 0.1133 - sparse_categorical_accuracy: 0.9646 - 1s/epoch - 3ms/step
# 157/157 - 1s - loss: 0.5028 - sparse_categorical_accuracy: 0.8328 - 572ms/epoch - 4ms/step
# 157/157 - 1s - loss: 0.2999 - sparse_categorical_accuracy: 0.9000 - 565ms/epoch - 4ms/step
# 157/157 - 1s - loss: 0.2890 - sparse_categorical_accuracy: 0.9026 - 563ms/epoch - 4ms/step
# Epoch 2/5
# 200/200 - 3s - loss: 0.3515 - sparse_categorical_accuracy: 0.8853 - 3s/epoch - 17ms/step
# 313/313 - 1s - loss: 0.1179 - sparse_categorical_accuracy: 0.9631 - 1s/epoch - 4ms/step
# 157/157 - 1s - loss: 0.3793 - sparse_categorical_accuracy: 0.8740 - 696ms/epoch - 4ms/step
# 157/157 - 1s - loss: 0.2611 - sparse_categorical_accuracy: 0.9158 - 728ms/epoch - 5ms/step
# 157/157 - 1s - loss: 0.2552 - sparse_categorical_accuracy: 0.9194 - 755ms/epoch - 5ms/step
# Epoch 3/5
# 200/200 - 4s - loss: 0.2558 - sparse_categorical_accuracy: 0.9151 - 4s/epoch - 20ms/step
# 313/313 - 2s - loss: 0.1009 - sparse_categorical_accuracy: 0.9691 - 2s/epoch - 5ms/step
# 157/157 - 1s - loss: 0.3077 - sparse_categorical_accuracy: 0.8974 - 1s/epoch - 9ms/step
# 157/157 - 1s - loss: 0.2136 - sparse_categorical_accuracy: 0.9328 - 1s/epoch - 8ms/step
# 157/157 - 1s - loss: 0.2102 - sparse_categorical_accuracy: 0.9348 - 825ms/epoch - 5ms/step
# Epoch 4/5
# 200/200 - 4s - loss: 0.2028 - sparse_categorical_accuracy: 0.9323 - 4s/epoch - 18ms/step
# 313/313 - 2s - loss: 0.1221 - sparse_categorical_accuracy: 0.9652 - 2s/epoch - 6ms/step
# 157/157 - 1s - loss: 0.3016 - sparse_categorical_accuracy: 0.8976 - 1s/epoch - 8ms/step
# 157/157 - 1s - loss: 0.2352 - sparse_categorical_accuracy: 0.9312 - 1s/epoch - 8ms/step
# 157/157 - 1s - loss: 0.2360 - sparse_categorical_accuracy: 0.9332 - 977ms/epoch - 6ms/step
# Epoch 5/5
# 200/200 - 4s - loss: 0.1639 - sparse_categorical_accuracy: 0.9448 - 4s/epoch - 18ms/step
# 313/313 - 2s - loss: 0.1142 - sparse_categorical_accuracy: 0.9663 - 2s/epoch - 7ms/step
# 157/157 - 2s - loss: 0.2795 - sparse_categorical_accuracy: 0.9086 - 2s/epoch - 10ms/step
# 157/157 - 1s - loss: 0.2249 - sparse_categorical_accuracy: 0.9320 - 1s/epoch - 8ms/step
# 157/157 - 1s - loss: 0.2201 - sparse_categorical_accuracy: 0.9348 - 871ms/epoch - 6ms/step

# %%
import tensorflow as tf

def generate_fgsm(image, model, epsilon):
    # Ensure the image has the correct shape
    image = tf.convert_to_tensor(image)
    image = tf.reshape(image, (1, *image.shape))

    with tf.GradientTape() as tape:
        tape.watch(image)
        prediction = model(image)
        target_class = tf.argmax(prediction[0])
        loss = tf.keras.losses.sparse_categorical_crossentropy(target_class, prediction)

    gradient = tape.gradient(loss, image)
    signed_grad = tf.sign(gradient)
    perturbed_image = image + epsilon * signed_grad
    perturbed_image = tf.clip_by_value(perturbed_image, 0, 1)  # Ensure pixel values are in [0, 1] range
    
    return perturbed_image.numpy()[0]

# %%
import tensorflow as tf
import numpy as np

def generate_carlini_l2(image, model, epsilon, max_iter, learning_rate):
    # Ensure the image has the correct shape
    image = tf.convert_to_tensor(image)
    image = tf.reshape(image, (1, *image.shape))

    # Initialize perturbed_image before the loop
    perturbed_image = tf.cast(image, dtype=tf.float32)

    # Define the objective function for the attack
    def objective_function(perturbed_image):
        prediction = model(perturbed_image)
        target_class = tf.argmax(prediction[0])
        f_x = prediction[0][target_class]
        return -f_x

    # Define the L2 norm penalty
    def l2_norm(perturbed_image):
        perturbed_image = tf.cast(perturbed_image, dtype=tf.float32)
        image_cast = tf.cast(image, dtype=tf.float32)
        return tf.reduce_sum(tf.square(perturbed_image - image_cast))

    # Define the gradient of the objective function
    @tf.custom_gradient
    def gradient_objective_function(perturbed_image):
        with tf.GradientTape() as tape:
            tape.watch(perturbed_image)
            loss = objective_function(perturbed_image)
        gradient = tape.gradient(loss, perturbed_image)
        def grad(d_loss):
            return d_loss * gradient
        return loss, grad
    
    prediction = model(image)
    target_class = tf.argmax(prediction[0])

    for i in range(max_iter):
        # Step 1: Compute the gradient of the objective function
        with tf.GradientTape() as tape:
            tape.watch(perturbed_image)
            loss = objective_function(perturbed_image) + epsilon * l2_norm(perturbed_image)
        gradient, = tape.gradient(loss, perturbed_image)

        # Step 2: Project the gradient onto the L2 sphere
        gradient = tf.nn.l2_normalize(gradient, axis=1)

        # Step 3: Update the perturbed image
        perturbed_image = perturbed_image + learning_rate * gradient

        # Step 4: Clip pixel values and ensure image validity
        perturbed_image = tf.clip_by_value(perturbed_image, 0, 1)

        # Step 5: Check if the image is now misclassified
        prediction = model(perturbed_image)
        if tf.argmax(prediction[0]) != target_class:
            break

    # Return the adversarial example
    return perturbed_image.numpy()[0]

# %%
import tensorflow as tf
import numpy as np

def generate_deepfool(image, model, epsilon=0.001, max_iter=100):
    # Ensure the image has the correct shape
    image = tf.convert_to_tensor(image)
    image = tf.reshape(image, (1, *image.shape))

    # Initialize perturbed_image before the loop
    perturbed_image = image

    for i in range(int(max_iter)):  # Convert max_iter to an integer
        # print(i)
        # Step 1: Compute the gradient of the loss with respect to the input image
        with tf.GradientTape() as tape:
            tape.watch(image)
            prediction = model(image)
            target_class = tf.argmax(prediction[0])
            loss = tf.keras.backend.sparse_categorical_crossentropy(target_class, prediction)

        gradient = tape.gradient(loss, image)
        gradient_norm = tf.linalg.norm(gradient)

        # Step 2: Compute the perturbation direction
        w = gradient / gradient_norm

        # Step 3: Compute the minimum perturbation required to reach the decision boundary
        f_x = prediction[0][target_class]
        perturbation = tf.reduce_sum(tf.abs(gradient)) / gradient_norm**2 * w
        r_star = tf.minimum(epsilon, tf.abs(f_x) / tf.cast(tf.linalg.norm(perturbation), tf.float32))

        # Step 4: Perturb the image and clip pixel values
        perturbed_image = image + tf.cast(r_star, perturbation.dtype) * perturbation
        perturbed_image = tf.clip_by_value(perturbed_image, 0, 1)


        # Step 5: Check if the image is now misclassified
        prediction = model(perturbed_image)
        if tf.argmax(prediction[0]) != target_class:
            # print("Stopped")
            break

        # Update the original image
        image = perturbed_image

    # Return the adversarial example
    return perturbed_image.numpy()[0]

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
import matplotlib.pyplot as plt

# Load the clean training dataset
(_, _), (train_images, train_labels) = tf.keras.datasets.mnist.load_data()
train_images = train_images / 255.0  # Normalize pixel values

# Load the clean test dataset
(_, _), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
test_images = test_images / 255.0  # Normalize pixel values

# Load the FCN model (replace with your model loading code)
fcn_model = models.load_model("../Models/Mnist/mnist_model_2LFCN.karas")

# Compile the model
fcn_model.compile(
    optimizer='adam',
    loss=SparseCategoricalCrossentropy(),
    metrics=[SparseCategoricalAccuracy()]
)

# Adversarial training parameters
epochs = 25
batch_size = 16
epsilon_fgs = 0.25  # FGSM epsilon value

# Lists to store accuracy for plotting
clean_test_accuracies = []
perturbed_test_accuracies_FGSM = []
perturbed_test_accuracies_CW = []
perturbed_test_accuracies_DF = []

# Define an epsilon value for the C&W untargeted attack
epsilon = 0.005
max_iter=50
learning_rate = 0.1

# Define parameters for the Deepfool attack
max_iter = 50
epsilon = 0.005

# Adversarial training loop
for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")

    # Randomly select a subset of 500 training samples
    indices_train = np.random.choice(len(train_images), 500, replace=False)
    train_images_200 = train_images[indices_train]
    perturbed_train_images = np.array([generate_fgsm(image, fcn_model, epsilon_fgs) for image in train_images_200])
    perturbed_train_labels = train_labels[indices_train]

    # Randomly select a subset of 100 testing samples and generate adversarial examples
    indices_test = np.random.choice(len(test_images), 100, replace=False)
    test_images_200 = test_images[indices_test]
    #FGSM
    perturbed_test_images_FGSM = np.array([generate_fgsm(image, fcn_model, epsilon_fgs) for image in test_images_200])
    perturbed_test_labels_FGSM = test_labels[indices_test]
    #CW
    perturbed_test_images_CW = np.array([generate_carlini_l2(image, fcn_model, epsilon, max_iter, learning_rate) for image in test_images_200])
    perturbed_test_labels_CW = test_labels[indices_test]
    #DF
    perturbed_test_images_DF = np.array([generate_deepfool(image, fcn_model, epsilon, max_iter) for image in test_images_200])
    perturbed_test_labels_DF = test_labels[indices_test]

    # Evaluate on clean test set
    test_loss, clean_test_accuracy = fcn_model.evaluate(test_images, test_labels)
    clean_test_accuracies.append(clean_test_accuracy)

    # Evaluate on perturbed test sets
    perturbed_test_accuracy_FGSM = fcn_model.evaluate(perturbed_test_images_FGSM, perturbed_test_labels_FGSM, verbose=2)[1]
    perturbed_test_accuracies_FGSM.append(perturbed_test_accuracy_FGSM)
    perturbed_test_accuracy_CW = fcn_model.evaluate(perturbed_test_images_CW, perturbed_test_labels_CW, verbose=2)[1]
    perturbed_test_accuracies_CW.append(perturbed_test_accuracy_CW)
    perturbed_test_accuracy_DF = fcn_model.evaluate(perturbed_test_images_DF, perturbed_test_labels_DF, verbose=2)[1]
    perturbed_test_accuracies_DF.append(perturbed_test_accuracy_DF)

    # Train on perturbed examples
    fcn_model.fit(perturbed_train_images, perturbed_train_labels, epochs=1, batch_size=batch_size, verbose=2)

# Plot the results
plt.plot(range(1, epochs+1), clean_test_accuracies, label='Clean Test Accuracy', marker='o')
plt.plot(range(1, epochs+1), perturbed_test_accuracies_FGSM, label='Perturbed Test Accuracy (FGSM)', marker='o')
plt.plot(range(1, epochs+1), perturbed_test_accuracies_CW, label='Perturbed Test Accuracy (CW)', marker='o')
plt.plot(range(1, epochs+1), perturbed_test_accuracies_DF, label='Perturbed Test Accuracy (DF)', marker='o')
plt.title('Adversarial Training (FGSM, 2LFCN)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/25
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0372 - sparse_categorical_accuracy: 0.9895
# 4/4 - 0s - loss: 3.2366 - sparse_categorical_accuracy: 0.3800 - 33ms/epoch - 8ms/step
# 4/4 - 0s - loss: 2.2782 - sparse_categorical_accuracy: 0.0100 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 1.4179 - sparse_categorical_accuracy: 0.0100 - 32ms/epoch - 8ms/step
# 32/32 - 1s - loss: 2.2938 - sparse_categorical_accuracy: 0.4700 - 1s/epoch - 47ms/step
# Epoch 2/25
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0800 - sparse_categorical_accuracy: 0.9761
# 4/4 - 0s - loss: 2.2808 - sparse_categorical_accuracy: 0.3700 - 32ms/epoch - 8ms/step
# 4/4 - 0s - loss: 1.5694 - sparse_categorical_accuracy: 0.0000e+00 - 30ms/epoch - 7ms/step
# 4/4 - 0s - loss: 0.9536 - sparse_categorical_accuracy: 0.0000e+00 - 28ms/epoch - 7ms/step
# 32/32 - 0s - loss: 1.7593 - sparse_categorical_accuracy: 0.4180 - 122ms/epoch - 4ms/step
# Epoch 3/25
# 313/313 [==============================] - 1s 5ms/step - loss: 0.0632 - sparse_categorical_accuracy: 0.9822
# 4/4 - 0s - loss: 1.8325 - sparse_categorical_accuracy: 0.3700 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 1.4683 - sparse_categorical_accuracy: 0.0000e+00 - 44ms/epoch - 11ms/step
# 4/4 - 0s - loss: 1.0203 - sparse_categorical_accuracy: 0.0000e+00 - 44ms/epoch - 11ms/step
# 32/32 - 0s - loss: 1.5954 - sparse_categorical_accuracy: 0.4620 - 162ms/epoch - 5ms/step
# Epoch 4/25
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1005 - sparse_categorical_accuracy: 0.9710
# 4/4 - 0s - loss: 1.5680 - sparse_categorical_accuracy: 0.5300 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 1.3733 - sparse_categorical_accuracy: 0.0400 - 36ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.8962 - sparse_categorical_accuracy: 0.0400 - 37ms/epoch - 9ms/step
# 32/32 - 0s - loss: 1.2917 - sparse_categorical_accuracy: 0.5800 - 178ms/epoch - 6ms/step
# Epoch 5/25
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0697 - sparse_categorical_accuracy: 0.9789
# 4/4 - 0s - loss: 1.1918 - sparse_categorical_accuracy: 0.6600 - 84ms/epoch - 21ms/step
# 4/4 - 0s - loss: 1.4419 - sparse_categorical_accuracy: 0.0000e+00 - 58ms/epoch - 15ms/step
# 4/4 - 0s - loss: 0.9805 - sparse_categorical_accuracy: 0.0000e+00 - 52ms/epoch - 13ms/step
# 32/32 - 0s - loss: 1.2775 - sparse_categorical_accuracy: 0.5380 - 225ms/epoch - 7ms/step
# Epoch 6/25
# 313/313 [==============================] - 2s 5ms/step - loss: 0.1016 - sparse_categorical_accuracy: 0.9726
# 4/4 - 0s - loss: 1.1297 - sparse_categorical_accuracy: 0.5600 - 48ms/epoch - 12ms/step
# 4/4 - 0s - loss: 1.2621 - sparse_categorical_accuracy: 0.0600 - 49ms/epoch - 12ms/step
# 4/4 - 0s - loss: 0.9484 - sparse_categorical_accuracy: 0.0600 - 60ms/epoch - 15ms/step
# 32/32 - 0s - loss: 1.1269 - sparse_categorical_accuracy: 0.6000 - 244ms/epoch - 8ms/step
# Epoch 7/25
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0933 - sparse_categorical_accuracy: 0.9771
# 4/4 - 0s - loss: 1.1149 - sparse_categorical_accuracy: 0.6400 - 58ms/epoch - 15ms/step
# 4/4 - 0s - loss: 1.2811 - sparse_categorical_accuracy: 0.0300 - 51ms/epoch - 13ms/step
# 4/4 - 0s - loss: 0.8874 - sparse_categorical_accuracy: 0.0300 - 52ms/epoch - 13ms/step
# 32/32 - 0s - loss: 1.1221 - sparse_categorical_accuracy: 0.6180 - 182ms/epoch - 6ms/step
# Epoch 8/25
# 313/313 [==============================] - 3s 11ms/step - loss: 0.1027 - sparse_categorical_accuracy: 0.9730
# 4/4 - 0s - loss: 0.8475 - sparse_categorical_accuracy: 0.6800 - 63ms/epoch - 16ms/step
# 4/4 - 0s - loss: 1.2622 - sparse_categorical_accuracy: 0.0300 - 49ms/epoch - 12ms/step
# 4/4 - 0s - loss: 0.9118 - sparse_categorical_accuracy: 0.0300 - 49ms/epoch - 12ms/step
# 32/32 - 0s - loss: 1.0079 - sparse_categorical_accuracy: 0.6460 - 213ms/epoch - 7ms/step
# Epoch 9/25
# 313/313 [==============================] - 1s 5ms/step - loss: 0.1006 - sparse_categorical_accuracy: 0.9706
# 4/4 - 0s - loss: 1.0692 - sparse_categorical_accuracy: 0.5900 - 44ms/epoch - 11ms/step
# 4/4 - 0s - loss: 1.2754 - sparse_categorical_accuracy: 0.0300 - 60ms/epoch - 15ms/step
# 4/4 - 0s - loss: 0.9282 - sparse_categorical_accuracy: 0.0400 - 42ms/epoch - 11ms/step
# 32/32 - 0s - loss: 0.9273 - sparse_categorical_accuracy: 0.6780 - 160ms/epoch - 5ms/step
# Epoch 10/25
# 313/313 [==============================] - 3s 8ms/step - loss: 0.1037 - sparse_categorical_accuracy: 0.9713
# 4/4 - 0s - loss: 1.1678 - sparse_categorical_accuracy: 0.6200 - 48ms/epoch - 12ms/step
# 4/4 - 0s - loss: 1.2515 - sparse_categorical_accuracy: 0.0300 - 82ms/epoch - 21ms/step
# 4/4 - 0s - loss: 0.9092 - sparse_categorical_accuracy: 0.0200 - 64ms/epoch - 16ms/step
# 32/32 - 0s - loss: 0.9330 - sparse_categorical_accuracy: 0.6560 - 326ms/epoch - 10ms/step
# Epoch 11/25
# 313/313 [==============================] - 2s 5ms/step - loss: 0.1049 - sparse_categorical_accuracy: 0.9725
# 4/4 - 0s - loss: 0.8083 - sparse_categorical_accuracy: 0.6600 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 1.2150 - sparse_categorical_accuracy: 0.0100 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.8740 - sparse_categorical_accuracy: 0.0100 - 46ms/epoch - 11ms/step
# 32/32 - 0s - loss: 0.8839 - sparse_categorical_accuracy: 0.6960 - 149ms/epoch - 5ms/step
# Epoch 12/25
# 313/313 [==============================] - 2s 5ms/step - loss: 0.1140 - sparse_categorical_accuracy: 0.9662
# 4/4 - 0s - loss: 1.0638 - sparse_categorical_accuracy: 0.6500 - 48ms/epoch - 12ms/step
# 4/4 - 0s - loss: 1.2635 - sparse_categorical_accuracy: 0.0100 - 52ms/epoch - 13ms/step
# 4/4 - 0s - loss: 0.8613 - sparse_categorical_accuracy: 0.0100 - 43ms/epoch - 11ms/step
# 32/32 - 0s - loss: 0.9675 - sparse_categorical_accuracy: 0.6160 - 170ms/epoch - 5ms/step
# Epoch 13/25
# 313/313 [==============================] - 2s 5ms/step - loss: 0.1056 - sparse_categorical_accuracy: 0.9703
# 4/4 - 0s - loss: 0.7680 - sparse_categorical_accuracy: 0.6900 - 41ms/epoch - 10ms/step
# 4/4 - 0s - loss: 1.2191 - sparse_categorical_accuracy: 0.0300 - 42ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.8792 - sparse_categorical_accuracy: 0.0300 - 44ms/epoch - 11ms/step
# 32/32 - 0s - loss: 0.9257 - sparse_categorical_accuracy: 0.6560 - 183ms/epoch - 6ms/step
# Epoch 14/25
# 313/313 [==============================] - 2s 5ms/step - loss: 0.1277 - sparse_categorical_accuracy: 0.9706
# 4/4 - 0s - loss: 0.8497 - sparse_categorical_accuracy: 0.6300 - 46ms/epoch - 11ms/step
# 4/4 - 0s - loss: 1.2520 - sparse_categorical_accuracy: 0.0500 - 45ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.9452 - sparse_categorical_accuracy: 0.0500 - 37ms/epoch - 9ms/step
# 32/32 - 0s - loss: 0.8415 - sparse_categorical_accuracy: 0.6880 - 206ms/epoch - 6ms/step
# Epoch 15/25
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0973 - sparse_categorical_accuracy: 0.9681
# 4/4 - 0s - loss: 0.9201 - sparse_categorical_accuracy: 0.6800 - 44ms/epoch - 11ms/step
# 4/4 - 0s - loss: 1.2030 - sparse_categorical_accuracy: 0.0300 - 44ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.9088 - sparse_categorical_accuracy: 0.0300 - 48ms/epoch - 12ms/step
# 32/32 - 0s - loss: 0.9257 - sparse_categorical_accuracy: 0.6700 - 192ms/epoch - 6ms/step
# Epoch 16/25
# 313/313 [==============================] - 1s 5ms/step - loss: 0.1204 - sparse_categorical_accuracy: 0.9704
# 4/4 - 0s - loss: 1.0627 - sparse_categorical_accuracy: 0.6500 - 47ms/epoch - 12ms/step
# 4/4 - 0s - loss: 1.1910 - sparse_categorical_accuracy: 0.0100 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.9232 - sparse_categorical_accuracy: 0.0100 - 40ms/epoch - 10ms/step
# 32/32 - 0s - loss: 0.8455 - sparse_categorical_accuracy: 0.6820 - 165ms/epoch - 5ms/step
# Epoch 17/25
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0974 - sparse_categorical_accuracy: 0.9730
# 4/4 - 0s - loss: 0.8328 - sparse_categorical_accuracy: 0.7100 - 41ms/epoch - 10ms/step
# 4/4 - 0s - loss: 1.2294 - sparse_categorical_accuracy: 0.0200 - 43ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.9290 - sparse_categorical_accuracy: 0.0300 - 43ms/epoch - 11ms/step
# 32/32 - 0s - loss: 0.7735 - sparse_categorical_accuracy: 0.6960 - 152ms/epoch - 5ms/step
# Epoch 18/25
# 313/313 [==============================] - 2s 5ms/step - loss: 0.1116 - sparse_categorical_accuracy: 0.9657
# 4/4 - 0s - loss: 0.9434 - sparse_categorical_accuracy: 0.6800 - 50ms/epoch - 12ms/step
# 4/4 - 0s - loss: 1.2551 - sparse_categorical_accuracy: 0.0200 - 51ms/epoch - 13ms/step
# 4/4 - 0s - loss: 0.9518 - sparse_categorical_accuracy: 0.0200 - 39ms/epoch - 10ms/step
# 32/32 - 0s - loss: 0.7326 - sparse_categorical_accuracy: 0.7260 - 164ms/epoch - 5ms/step
# Epoch 19/25
# 313/313 [==============================] - 2s 5ms/step - loss: 0.1096 - sparse_categorical_accuracy: 0.9706
# 4/4 - 0s - loss: 0.8836 - sparse_categorical_accuracy: 0.6600 - 42ms/epoch - 11ms/step
# 4/4 - 0s - loss: 1.2061 - sparse_categorical_accuracy: 0.0200 - 38ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.8990 - sparse_categorical_accuracy: 0.0200 - 40ms/epoch - 10ms/step
# 32/32 - 0s - loss: 0.8431 - sparse_categorical_accuracy: 0.6660 - 166ms/epoch - 5ms/step
# Epoch 20/25
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0928 - sparse_categorical_accuracy: 0.9720
# 4/4 - 0s - loss: 0.9247 - sparse_categorical_accuracy: 0.6000 - 42ms/epoch - 11ms/step
# 4/4 - 0s - loss: 1.2565 - sparse_categorical_accuracy: 0.0200 - 42ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.9169 - sparse_categorical_accuracy: 0.0200 - 51ms/epoch - 13ms/step
# 32/32 - 0s - loss: 0.7900 - sparse_categorical_accuracy: 0.6860 - 162ms/epoch - 5ms/step
# Epoch 21/25
# 313/313 [==============================] - 1s 5ms/step - loss: 0.1000 - sparse_categorical_accuracy: 0.9685
# 4/4 - 0s - loss: 0.8152 - sparse_categorical_accuracy: 0.7000 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 1.1825 - sparse_categorical_accuracy: 0.0300 - 35ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.8848 - sparse_categorical_accuracy: 0.0300 - 43ms/epoch - 11ms/step
# 32/32 - 0s - loss: 0.7117 - sparse_categorical_accuracy: 0.7120 - 146ms/epoch - 5ms/step
# Epoch 22/25
# 313/313 [==============================] - 1s 5ms/step - loss: 0.0893 - sparse_categorical_accuracy: 0.9744
# 4/4 - 0s - loss: 0.9743 - sparse_categorical_accuracy: 0.6100 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 1.1946 - sparse_categorical_accuracy: 0.0200 - 47ms/epoch - 12ms/step
# 4/4 - 0s - loss: 0.8947 - sparse_categorical_accuracy: 0.0200 - 37ms/epoch - 9ms/step
# 32/32 - 0s - loss: 0.8143 - sparse_categorical_accuracy: 0.6860 - 150ms/epoch - 5ms/step
# Epoch 23/25
# 313/313 [==============================] - 1s 5ms/step - loss: 0.1011 - sparse_categorical_accuracy: 0.9686
# 4/4 - 0s - loss: 0.8118 - sparse_categorical_accuracy: 0.7200 - 42ms/epoch - 10ms/step
# 4/4 - 0s - loss: 1.1472 - sparse_categorical_accuracy: 0.0100 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 0.8500 - sparse_categorical_accuracy: 0.0200 - 40ms/epoch - 10ms/step
# 32/32 - 0s - loss: 0.7279 - sparse_categorical_accuracy: 0.7500 - 155ms/epoch - 5ms/step
# Epoch 24/25
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1081 - sparse_categorical_accuracy: 0.9683
# 4/4 - 0s - loss: 0.8179 - sparse_categorical_accuracy: 0.7200 - 43ms/epoch - 11ms/step
# 4/4 - 0s - loss: 1.1391 - sparse_categorical_accuracy: 0.0100 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.8910 - sparse_categorical_accuracy: 0.0100 - 39ms/epoch - 10ms/step
# 32/32 - 0s - loss: 0.6912 - sparse_categorical_accuracy: 0.7240 - 157ms/epoch - 5ms/step
# Epoch 25/25
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0926 - sparse_categorical_accuracy: 0.9704
# 4/4 - 0s - loss: 0.8066 - sparse_categorical_accuracy: 0.7300 - 38ms/epoch - 9ms/step
# 4/4 - 0s - loss: 1.1951 - sparse_categorical_accuracy: 0.0100 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.8527 - sparse_categorical_accuracy: 0.0100 - 40ms/epoch - 10ms/step
# 32/32 - 0s - loss: 0.8017 - sparse_categorical_accuracy: 0.7080 - 158ms/epoch - 5ms/step

# %%
fcn_model.save("../Models/Mnist/mnist_model_2LFCN_ADV_FGSM.karas")
# Out:
# INFO:tensorflow:Assets written to: ../Models/Mnist/mnist_model_2LFCN_ADV_FGSM.karas\assets
# INFO:tensorflow:Assets written to: ../Models/Mnist/mnist_model_2LFCN_ADV_FGSM.karas\assets

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.metrics import SparseCategoricalAccuracy
import matplotlib.pyplot as plt

# Load the clean training dataset
(_, _), (train_images, train_labels) = tf.keras.datasets.mnist.load_data()
train_images = train_images / 255.0  # Normalize pixel values

# Load the clean test dataset
(_, _), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
test_images = test_images / 255.0  # Normalize pixel values

# Load the FCN model (replace with your model loading code)
fcn_model = models.load_model("../Models/Mnist/mnist_model_LENET.karas")

# Compile the model
fcn_model.compile(
    optimizer='adam',
    loss=SparseCategoricalCrossentropy(),
    metrics=[SparseCategoricalAccuracy()]
)

# Adversarial training parameters
epochs = 25
batch_size = 16
epsilon_fgs = 0.25  # FGSM epsilon value

# Lists to store accuracy for plotting
clean_test_accuracies = []
perturbed_test_accuracies_FGSM = []
perturbed_test_accuracies_CW = []
perturbed_test_accuracies_DF = []

# Define an epsilon value for the C&W untargeted attack
epsilon = 0.005
max_iter=50
learning_rate = 0.1

# Define parameters for the Deepfool attack
max_iter = 50
epsilon = 0.005

# Adversarial training loop
for epoch in range(epochs):
    print(f"Epoch {epoch + 1}/{epochs}")

    # Randomly select a subset of 500 training samples
    indices_train = np.random.choice(len(train_images), 500, replace=False)
    train_images_200 = train_images[indices_train]
    perturbed_train_images = np.array([generate_fgsm(image, fcn_model, epsilon_fgs) for image in train_images_200])
    perturbed_train_labels = train_labels[indices_train]

    # Randomly select a subset of 100 testing samples and generate adversarial examples
    indices_test = np.random.choice(len(test_images), 100, replace=False)
    test_images_200 = test_images[indices_test]
    #FGSM
    perturbed_test_images_FGSM = np.array([generate_fgsm(image, fcn_model, epsilon_fgs) for image in test_images_200])
    perturbed_test_labels_FGSM = test_labels[indices_test]
    #CW
    perturbed_test_images_CW = np.array([generate_carlini_l2(image, fcn_model, epsilon, max_iter, learning_rate) for image in test_images_200])
    perturbed_test_labels_CW = test_labels[indices_test]
    #DF
    perturbed_test_images_DF = np.array([generate_deepfool(image, fcn_model, epsilon, max_iter) for image in test_images_200])
    perturbed_test_labels_DF = test_labels[indices_test]

    # Evaluate on clean test set
    test_loss, clean_test_accuracy = fcn_model.evaluate(test_images, test_labels)
    clean_test_accuracies.append(clean_test_accuracy)

    # Evaluate on perturbed test sets
    perturbed_test_accuracy_FGSM = fcn_model.evaluate(perturbed_test_images_FGSM, perturbed_test_labels_FGSM, verbose=2)[1]
    perturbed_test_accuracies_FGSM.append(perturbed_test_accuracy_FGSM)
    perturbed_test_accuracy_CW = fcn_model.evaluate(perturbed_test_images_CW, perturbed_test_labels_CW, verbose=2)[1]
    perturbed_test_accuracies_CW.append(perturbed_test_accuracy_CW)
    perturbed_test_accuracy_DF = fcn_model.evaluate(perturbed_test_images_DF, perturbed_test_labels_DF, verbose=2)[1]
    perturbed_test_accuracies_DF.append(perturbed_test_accuracy_DF)

    # Train on perturbed examples
    fcn_model.fit(perturbed_train_images, perturbed_train_labels, epochs=1, batch_size=batch_size, verbose=2)

# Plot the results
plt.plot(range(1, epochs+1), clean_test_accuracies, label='Clean Test Accuracy', marker='o')
plt.plot(range(1, epochs+1), perturbed_test_accuracies_FGSM, label='Perturbed Test Accuracy (FGSM)', marker='o')
plt.plot(range(1, epochs+1), perturbed_test_accuracies_CW, label='Perturbed Test Accuracy (CW)', marker='o')
plt.plot(range(1, epochs+1), perturbed_test_accuracies_DF, label='Perturbed Test Accuracy (DF)', marker='o')
plt.title('Adversarial Training (FGSM, LENET)')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# Epoch 1/25
# 313/313 [==============================] - 3s 7ms/step - loss: 0.0348 - sparse_categorical_accuracy: 0.9899
# 4/4 - 0s - loss: 3.5065 - sparse_categorical_accuracy: 0.2900 - 77ms/epoch - 19ms/step
# 4/4 - 0s - loss: 2.0660 - sparse_categorical_accuracy: 0.0200 - 78ms/epoch - 19ms/step
# 4/4 - 0s - loss: 1.1889 - sparse_categorical_accuracy: 0.0200 - 46ms/epoch - 12ms/step
# 32/32 - 2s - loss: 2.3139 - sparse_categorical_accuracy: 0.4280 - 2s/epoch - 60ms/step
# Epoch 2/25
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0889 - sparse_categorical_accuracy: 0.9745
# 4/4 - 0s - loss: 2.1943 - sparse_categorical_accuracy: 0.3400 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 1.4684 - sparse_categorical_accuracy: 0.0100 - 48ms/epoch - 12ms/step
# 4/4 - 0s - loss: 0.8833 - sparse_categorical_accuracy: 0.0100 - 59ms/epoch - 15ms/step
# 32/32 - 0s - loss: 1.8909 - sparse_categorical_accuracy: 0.4160 - 196ms/epoch - 6ms/step
# Epoch 3/25
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0949 - sparse_categorical_accuracy: 0.9784
# 4/4 - 0s - loss: 1.5659 - sparse_categorical_accuracy: 0.4300 - 37ms/epoch - 9ms/step
# 4/4 - 0s - loss: 1.3539 - sparse_categorical_accuracy: 0.0100 - 43ms/epoch - 11ms/step
# 4/4 - 0s - loss: 1.0311 - sparse_categorical_accuracy: 0.0100 - 42ms/epoch - 10ms/step
# 32/32 - 0s - loss: 1.5377 - sparse_categorical_accuracy: 0.4660 - 163ms/epoch - 5ms/step
# Epoch 4/25
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0994 - sparse_categorical_accuracy: 0.9759
# 4/4 - 0s - loss: 1.4105 - sparse_categorical_accuracy: 0.5300 - 42ms/epoch - 11ms/step
# 4/4 - 0s - loss: 1.2949 - sparse_categorical_accuracy: 0.0400 - 42ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.9401 - sparse_categorical_accuracy: 0.0400 - 43ms/epoch - 11ms/step
# 32/32 - 0s - loss: 1.3099 - sparse_categorical_accuracy: 0.5760 - 157ms/epoch - 5ms/step
# Epoch 5/25
# 313/313 [==============================] - 2s 5ms/step - loss: 0.1051 - sparse_categorical_accuracy: 0.9745
# 4/4 - 0s - loss: 1.2422 - sparse_categorical_accuracy: 0.5600 - 56ms/epoch - 14ms/step
# 4/4 - 0s - loss: 1.2684 - sparse_categorical_accuracy: 0.0400 - 83ms/epoch - 21ms/step
# 4/4 - 0s - loss: 0.9307 - sparse_categorical_accuracy: 0.0400 - 64ms/epoch - 16ms/step
# 32/32 - 0s - loss: 1.2770 - sparse_categorical_accuracy: 0.5580 - 241ms/epoch - 8ms/step
# Epoch 6/25
# 313/313 [==============================] - 2s 7ms/step - loss: 0.1036 - sparse_categorical_accuracy: 0.9737
# 4/4 - 0s - loss: 1.1820 - sparse_categorical_accuracy: 0.5700 - 55ms/epoch - 14ms/step
# 4/4 - 0s - loss: 1.3229 - sparse_categorical_accuracy: 0.0100 - 54ms/epoch - 13ms/step
# 4/4 - 0s - loss: 0.9952 - sparse_categorical_accuracy: 0.0200 - 59ms/epoch - 15ms/step
# 32/32 - 0s - loss: 1.1925 - sparse_categorical_accuracy: 0.5760 - 192ms/epoch - 6ms/step
# Epoch 7/25
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0982 - sparse_categorical_accuracy: 0.9762
# 4/4 - 0s - loss: 1.0203 - sparse_categorical_accuracy: 0.6000 - 45ms/epoch - 11ms/step
# 4/4 - 0s - loss: 1.2212 - sparse_categorical_accuracy: 0.0100 - 62ms/epoch - 15ms/step
# 4/4 - 0s - loss: 0.9033 - sparse_categorical_accuracy: 0.0100 - 61ms/epoch - 15ms/step
# 32/32 - 0s - loss: 0.9900 - sparse_categorical_accuracy: 0.6180 - 187ms/epoch - 6ms/step
# Epoch 8/25
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0967 - sparse_categorical_accuracy: 0.9754
# 4/4 - 0s - loss: 1.0678 - sparse_categorical_accuracy: 0.6800 - 53ms/epoch - 13ms/step
# 4/4 - 0s - loss: 1.3209 - sparse_categorical_accuracy: 0.0400 - 65ms/epoch - 16ms/step
# 4/4 - 0s - loss: 0.9465 - sparse_categorical_accuracy: 0.0400 - 69ms/epoch - 17ms/step
# 32/32 - 0s - loss: 1.0229 - sparse_categorical_accuracy: 0.6320 - 184ms/epoch - 6ms/step
# Epoch 9/25
# 313/313 [==============================] - 2s 7ms/step - loss: 0.1084 - sparse_categorical_accuracy: 0.9734
# 4/4 - 0s - loss: 1.3142 - sparse_categorical_accuracy: 0.5100 - 52ms/epoch - 13ms/step
# 4/4 - 0s - loss: 1.2729 - sparse_categorical_accuracy: 0.0100 - 51ms/epoch - 13ms/step
# 4/4 - 0s - loss: 0.8835 - sparse_categorical_accuracy: 0.0100 - 60ms/epoch - 15ms/step
# 32/32 - 0s - loss: 1.1055 - sparse_categorical_accuracy: 0.6100 - 203ms/epoch - 6ms/step
# Epoch 10/25
# 313/313 [==============================] - 2s 7ms/step - loss: 0.1223 - sparse_categorical_accuracy: 0.9684
# 4/4 - 0s - loss: 1.3225 - sparse_categorical_accuracy: 0.5700 - 49ms/epoch - 12ms/step
# 4/4 - 0s - loss: 1.3601 - sparse_categorical_accuracy: 0.0200 - 45ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.9569 - sparse_categorical_accuracy: 0.0200 - 57ms/epoch - 14ms/step
# 32/32 - 0s - loss: 1.1064 - sparse_categorical_accuracy: 0.6480 - 175ms/epoch - 5ms/step
# Epoch 11/25
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0983 - sparse_categorical_accuracy: 0.9781
# 4/4 - 0s - loss: 1.1075 - sparse_categorical_accuracy: 0.5900 - 68ms/epoch - 17ms/step
# 4/4 - 0s - loss: 1.2631 - sparse_categorical_accuracy: 0.0300 - 71ms/epoch - 18ms/step
# 4/4 - 0s - loss: 0.9476 - sparse_categorical_accuracy: 0.0300 - 68ms/epoch - 17ms/step
# 32/32 - 0s - loss: 0.9019 - sparse_categorical_accuracy: 0.6280 - 189ms/epoch - 6ms/step
# Epoch 12/25
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1251 - sparse_categorical_accuracy: 0.9707
# 4/4 - 0s - loss: 0.8851 - sparse_categorical_accuracy: 0.7200 - 44ms/epoch - 11ms/step
# 4/4 - 0s - loss: 1.2107 - sparse_categorical_accuracy: 0.0200 - 50ms/epoch - 13ms/step
# 4/4 - 0s - loss: 0.8890 - sparse_categorical_accuracy: 0.0200 - 51ms/epoch - 13ms/step
# 32/32 - 0s - loss: 0.8871 - sparse_categorical_accuracy: 0.6800 - 172ms/epoch - 5ms/step
# Epoch 13/25
# 313/313 [==============================] - 2s 7ms/step - loss: 0.0941 - sparse_categorical_accuracy: 0.9783
# 4/4 - 0s - loss: 0.8187 - sparse_categorical_accuracy: 0.7100 - 43ms/epoch - 11ms/step
# 4/4 - 0s - loss: 1.2275 - sparse_categorical_accuracy: 0.0100 - 51ms/epoch - 13ms/step
# 4/4 - 0s - loss: 0.9289 - sparse_categorical_accuracy: 0.0100 - 55ms/epoch - 14ms/step
# 32/32 - 0s - loss: 0.8940 - sparse_categorical_accuracy: 0.6760 - 155ms/epoch - 5ms/step
# Epoch 14/25
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1047 - sparse_categorical_accuracy: 0.9747
# 4/4 - 0s - loss: 0.7876 - sparse_categorical_accuracy: 0.7000 - 53ms/epoch - 13ms/step
# 4/4 - 0s - loss: 1.1918 - sparse_categorical_accuracy: 0.0300 - 61ms/epoch - 15ms/step
# 4/4 - 0s - loss: 0.8895 - sparse_categorical_accuracy: 0.0300 - 60ms/epoch - 15ms/step
# 32/32 - 0s - loss: 0.7959 - sparse_categorical_accuracy: 0.7100 - 173ms/epoch - 5ms/step
# Epoch 15/25
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0897 - sparse_categorical_accuracy: 0.9748
# 4/4 - 0s - loss: 1.0189 - sparse_categorical_accuracy: 0.6400 - 45ms/epoch - 11ms/step
# 4/4 - 0s - loss: 1.2777 - sparse_categorical_accuracy: 0.0100 - 64ms/epoch - 16ms/step
# 4/4 - 0s - loss: 0.8757 - sparse_categorical_accuracy: 0.0100 - 43ms/epoch - 11ms/step
# 32/32 - 0s - loss: 0.8617 - sparse_categorical_accuracy: 0.6840 - 248ms/epoch - 8ms/step
# Epoch 16/25
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0931 - sparse_categorical_accuracy: 0.9793
# 4/4 - 0s - loss: 1.0111 - sparse_categorical_accuracy: 0.6400 - 51ms/epoch - 13ms/step
# 4/4 - 0s - loss: 1.2583 - sparse_categorical_accuracy: 0.0000e+00 - 61ms/epoch - 15ms/step
# 4/4 - 0s - loss: 0.9231 - sparse_categorical_accuracy: 0.0100 - 59ms/epoch - 15ms/step
# 32/32 - 0s - loss: 0.9594 - sparse_categorical_accuracy: 0.6380 - 163ms/epoch - 5ms/step
# Epoch 17/25
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0978 - sparse_categorical_accuracy: 0.9783
# 4/4 - 0s - loss: 0.8982 - sparse_categorical_accuracy: 0.6900 - 46ms/epoch - 12ms/step
# 4/4 - 0s - loss: 1.2878 - sparse_categorical_accuracy: 0.0200 - 67ms/epoch - 17ms/step
# 4/4 - 0s - loss: 0.9208 - sparse_categorical_accuracy: 0.0200 - 58ms/epoch - 15ms/step
# 32/32 - 0s - loss: 0.8877 - sparse_categorical_accuracy: 0.6700 - 163ms/epoch - 5ms/step
# Epoch 18/25
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1189 - sparse_categorical_accuracy: 0.9733
# 4/4 - 0s - loss: 0.8923 - sparse_categorical_accuracy: 0.7200 - 43ms/epoch - 11ms/step
# 4/4 - 0s - loss: 1.2724 - sparse_categorical_accuracy: 0.0300 - 41ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.8642 - sparse_categorical_accuracy: 0.0300 - 43ms/epoch - 11ms/step
# 32/32 - 0s - loss: 0.8452 - sparse_categorical_accuracy: 0.7040 - 160ms/epoch - 5ms/step
# Epoch 19/25
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1003 - sparse_categorical_accuracy: 0.9776
# 4/4 - 0s - loss: 0.8343 - sparse_categorical_accuracy: 0.6800 - 47ms/epoch - 12ms/step
# 4/4 - 0s - loss: 1.1616 - sparse_categorical_accuracy: 0.0100 - 44ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.9084 - sparse_categorical_accuracy: 0.0100 - 41ms/epoch - 10ms/step
# 32/32 - 0s - loss: 0.8799 - sparse_categorical_accuracy: 0.6920 - 166ms/epoch - 5ms/step
# Epoch 20/25
# 313/313 [==============================] - 2s 5ms/step - loss: 0.1072 - sparse_categorical_accuracy: 0.9724
# 4/4 - 0s - loss: 0.9160 - sparse_categorical_accuracy: 0.7000 - 44ms/epoch - 11ms/step
# 4/4 - 0s - loss: 1.2566 - sparse_categorical_accuracy: 0.0000e+00 - 43ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.9054 - sparse_categorical_accuracy: 0.0000e+00 - 49ms/epoch - 12ms/step
# 32/32 - 0s - loss: 0.8237 - sparse_categorical_accuracy: 0.6860 - 170ms/epoch - 5ms/step
# Epoch 21/25
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0939 - sparse_categorical_accuracy: 0.9765
# 4/4 - 0s - loss: 0.7757 - sparse_categorical_accuracy: 0.7100 - 52ms/epoch - 13ms/step
# 4/4 - 0s - loss: 1.2775 - sparse_categorical_accuracy: 0.0100 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.9414 - sparse_categorical_accuracy: 0.0100 - 43ms/epoch - 11ms/step
# 32/32 - 0s - loss: 0.7924 - sparse_categorical_accuracy: 0.7220 - 167ms/epoch - 5ms/step
# Epoch 22/25
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0960 - sparse_categorical_accuracy: 0.9755
# 4/4 - 0s - loss: 0.7402 - sparse_categorical_accuracy: 0.6800 - 41ms/epoch - 10ms/step
# 4/4 - 0s - loss: 1.2059 - sparse_categorical_accuracy: 0.0000e+00 - 42ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.8970 - sparse_categorical_accuracy: 0.0000e+00 - 43ms/epoch - 11ms/step
# 32/32 - 0s - loss: 0.8669 - sparse_categorical_accuracy: 0.7020 - 201ms/epoch - 6ms/step
# Epoch 23/25
# 313/313 [==============================] - 2s 6ms/step - loss: 0.1032 - sparse_categorical_accuracy: 0.9738
# 4/4 - 0s - loss: 0.6542 - sparse_categorical_accuracy: 0.7600 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 1.2190 - sparse_categorical_accuracy: 0.0000e+00 - 44ms/epoch - 11ms/step
# 4/4 - 0s - loss: 0.9110 - sparse_categorical_accuracy: 0.0000e+00 - 42ms/epoch - 11ms/step
# 32/32 - 0s - loss: 0.7223 - sparse_categorical_accuracy: 0.7580 - 149ms/epoch - 5ms/step
# Epoch 24/25
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0830 - sparse_categorical_accuracy: 0.9758
# 4/4 - 0s - loss: 0.5564 - sparse_categorical_accuracy: 0.8400 - 39ms/epoch - 10ms/step
# 4/4 - 0s - loss: 1.2193 - sparse_categorical_accuracy: 0.0200 - 42ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.8856 - sparse_categorical_accuracy: 0.0200 - 44ms/epoch - 11ms/step
# 32/32 - 0s - loss: 0.7595 - sparse_categorical_accuracy: 0.7060 - 162ms/epoch - 5ms/step
# Epoch 25/25
# 313/313 [==============================] - 2s 5ms/step - loss: 0.0873 - sparse_categorical_accuracy: 0.9790
# 4/4 - 0s - loss: 0.7247 - sparse_categorical_accuracy: 0.7300 - 45ms/epoch - 11ms/step
# 4/4 - 0s - loss: 1.2134 - sparse_categorical_accuracy: 0.0100 - 40ms/epoch - 10ms/step
# 4/4 - 0s - loss: 0.8475 - sparse_categorical_accuracy: 0.0100 - 39ms/epoch - 10ms/step
# 32/32 - 0s - loss: 0.7194 - sparse_categorical_accuracy: 0.7300 - 171ms/epoch - 5ms/step

# %%
fcn_model.save("../Models/Mnist/mnist_model_LENET_ADV_FGSM.karas")
# Out:
# INFO:tensorflow:Assets written to: ../Models/Mnist/mnist_model_LENET_ADV_FGSM.karas\assets
# INFO:tensorflow:Assets written to: ../Models/Mnist/mnist_model_LENET_ADV_FGSM.karas\assets
